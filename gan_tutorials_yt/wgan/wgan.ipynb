# %% [markdown]
# ## WGAN
#
# Youtube Resource: https://youtu.be/pG0QZ7OddX4
#
# Sorta Insightful Blog Link: https://www.alexirpan.com/2017/02/22/wasserstein-gan.html
#
# Wasserstein GAN: https://arxiv.org/abs/1701.07875
#
# Improved Training of Wasserstein GAN: https://arxiv.org/abs/1704.00028

# %%
print("Wasserstein GAN Implementation from Scratch")
# Out:
# Wasserstein GAN Implementation from Scratch

# %%
# make sure to load tensorboard or reload if already loaded 
# %load_ext tensorboard

# %%
# start the tensorboard server (default is port 6006)
# %tensorboard --logdir=logs/ --reload_interval=5
# Out:
#       <iframe id="tensorboard-frame-534979dcd696e527" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-534979dcd696e527");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import torch
import torch.nn as nn

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # Input: N x channels_img x 64 x 64
            nn.Conv2d(channels_img, features_d, kernel_size=4, stride=2, padding=1),    # 32x32
            nn.LeakyReLU(0.2),
            self._block(features_d, features_d * 2, 4,2,1),     # 16x16
            self._block(features_d * 2, features_d * 4, 4,2,1), # 8x8
            self._block(features_d*4, features_d * 8, 4,2,1),   # 4x4
            nn.Conv2d(features_d*8, 1, kernel_size=4, stride=2, padding=0),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False,),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self,x):
        return self.disc(x)

# %%
class Generator(nn.Module):
    def __init__(self, z_dim, channels_img, features_g):
        super(Generator, self).__init__()
        self.gen = nn.Sequential(
            # Input: N x z_dim x 1 x 1
            self._block(z_dim, features_g*16, 4,1,0),   # N x f_g*16 x 4 x 4
            self._block(features_g*16, features_g*8, 4,2,1),    # 8x8
            self._block(features_g*8, features_g*4, 4,2,1),     # 16x16
            self._block(features_g*4, features_g*2, 4,2,1),     # 32x32
            nn.ConvTranspose2d(
                features_g*2, channels_img, kernel_size=4, stride=2, padding=1,
            ),      # 64x64
            nn.Tanh(),  # [-1,1]  
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels, out_channels, kernel_size, stride, padding, bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.gen(x)

# %%
# Mean=0, standatd deviaiton = 0.02
def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
def test():
    N, in_channels, H, W = 8,3,64,64
    z_dim = 100
    x = torch.randn((N, in_channels, H, W))
    disc = Discriminator(in_channels, 8)
    initialize_weights(disc)
    assert disc(x).shape == (N,1,1,1)
    
    gen = Generator(z_dim, in_channels, 8)
    z = torch.randn((N, z_dim, 1, 1))
    initialize_weights(gen)
    
    assert gen(z).shape == (N, in_channels, H, W)
    print("Success")

# %%
test()
# Out:
# Success

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
# from model import Discriminator, Generator, initialize_weights

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
LEARNING_RATE = 5e-5
BATCH_SIZE = 64
IMAGE_SIZE = 64
CHANNELS_IMG = 3    # make it 1 if you are training on a grayscale image
Z_DIM = 100
NUM_EPOCHS = 5      # It will take a lot of time coz there are lots of images to process
FEATURES_DISC = 64
FEATURES_GEN = 64
CRITIC_ITERATIONS = 5
WEIGHT_CLIP = 0.01

# %%
transforms = transforms.Compose(
    [
        transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.5 for _ in range(CHANNELS_IMG)], [0.5 for _ in range(CHANNELS_IMG)]
        ),
    ]
)

# %%
# dataset = datasets.MNIST(root="dataset/", train=True, transform=transforms, download=True)
dataset = datasets.ImageFolder(root="../dcgan/celebA_dataset/", transform=transforms)

dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

gen = Generator(Z_DIM, CHANNELS_IMG, FEATURES_GEN).to(device)
critic = Discriminator(CHANNELS_IMG, FEATURES_DISC).to(device)

initialize_weights(gen)
initialize_weights(critic)

opt_gen = optim.RMSprop(gen.parameters(), lr=LEARNING_RATE)
opt_critic = optim.RMSprop(critic.parameters(), lr=LEARNING_RATE)


fixed_noise = torch.randn(32, Z_DIM, 1,1).to(device)
writer_real = SummaryWriter(f"logs/real")
writer_fake = SummaryWriter(f"logs/fake")

step = 0

## Send both the networks to training modes
gen.train()
critic.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#   )
# )

# %%
for epoch in range(NUM_EPOCHS):
    for batch_idx, (real, _) in enumerate(dataloader):
        real = real.to(device)
        
        for _ in range(CRITIC_ITERATIONS):
            noise = torch.randn(BATCH_SIZE, Z_DIM, 1, 1).to(device)
            fake = gen(noise)
            critic_real = critic(real).reshape(-1)
            critic_fake = critic(fake).reshape(-1)

            loss_critic = -(torch.mean(critic_real) - torch.mean(critic_fake))
            critic.zero_grad()
            loss_critic.backward(retain_graph=True)
            opt_critic.step()

            for p in critic.parameters():
                p.data.clamp_(-WEIGHT_CLIP, WEIGHT_CLIP)

        ### Train Generator: min -E(critic(gen_fake))
        output = critic(fake).reshape(-1)
        loss_gen = -torch.mean(output)
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()
        
        ###  Print Losses occasionally and print to tensorboard
        if batch_idx % 100 == 0:
            print(f"Epoch [{epoch}/{NUM_EPOCHS} Batch {batch_idx}/{len(dataloader)} \n Loss D: {loss_critic:.4f}, Loss G: {loss_gen:.4f}]")

            with torch.no_grad():
                fake = gen(fixed_noise)
                # Take out (upto) 32 examples
                img_grid_real = torchvision.utils.make_grid(
                    real[:32], normalize=True
                )
                img_grid_fake = torchvision.utils.make_grid(
                    fake[:32], normalize=True
                )

                writer_real.add_image("Real", img_grid_real, global_step=step)

                writer_fake.add_image("Fake", img_grid_fake, global_step=step)
            
            step += 1
# Out:
# Epoch [0/5 Batch 0/3166
#  Loss D: -1.5017, Loss G: 0.7073]
# Epoch [0/5 Batch 100/3166
#  Loss D: -1.5081, Loss G: 0.7082]
# Epoch [0/5 Batch 200/3166
#  Loss D: -1.5091, Loss G: 0.7074]
# Epoch [0/5 Batch 300/3166
#  Loss D: -1.5131, Loss G: 0.7078]
# Epoch [0/5 Batch 400/3166
#  Loss D: -1.5109, Loss G: 0.7072]
# Epoch [0/5 Batch 500/3166
#  Loss D: -1.5182, Loss G: 0.7089]
# Epoch [0/5 Batch 600/3166
#  Loss D: -1.5183, Loss G: 0.7089]
# Epoch [0/5 Batch 700/3166
#  Loss D: -1.5168, Loss G: 0.7082]
# Epoch [0/5 Batch 800/3166
#  Loss D: -1.5189, Loss G: 0.7091]
# Epoch [0/5 Batch 900/3166
#  Loss D: -1.5163, Loss G: 0.7082]
# Epoch [0/5 Batch 1000/3166
#  Loss D: -1.5178, Loss G: 0.7084]
# Epoch [0/5 Batch 1100/3166
#  Loss D: -1.5076, Loss G: 0.7062]
# Epoch [0/5 Batch 1200/3166
#  Loss D: -1.5139, Loss G: 0.7080]
# Epoch [0/5 Batch 1300/3166
#  Loss D: -1.5153, Loss G: 0.7082]
# Epoch [0/5 Batch 1400/3166
#  Loss D: -1.5184, Loss G: 0.7112]
# Epoch [0/5 Batch 1500/3166
#  Loss D: -1.5166, Loss G: 0.7082]
# Epoch [0/5 Batch 1600/3166
#  Loss D: -1.4769, Loss G: 0.6981]
# Epoch [0/5 Batch 1700/3166
#  Loss D: -1.5175, Loss G: 0.7089]
# Epoch [0/5 Batch 1800/3166
#  Loss D: -1.5162, Loss G: 0.7094]
# Epoch [0/5 Batch 1900/3166
#  Loss D: -1.4875, Loss G: 0.6947]
# Epoch [0/5 Batch 2000/3166
#  Loss D: -1.5129, Loss G: 0.7071]
# Epoch [0/5 Batch 2100/3166
#  Loss D: -1.5110, Loss G: 0.7064]
# Epoch [0/5 Batch 2200/3166
#  Loss D: -1.5101, Loss G: 0.7085]
# Epoch [0/5 Batch 2300/3166
#  Loss D: -1.5124, Loss G: 0.7076]
# Epoch [0/5 Batch 2400/3166
#  Loss D: -1.5105, Loss G: 0.7054]
# Epoch [0/5 Batch 2500/3166
#  Loss D: -1.5046, Loss G: 0.7025]
# Epoch [0/5 Batch 2600/3166
#  Loss D: -1.5077, Loss G: 0.7043]
# Epoch [0/5 Batch 2700/3166
#  Loss D: -1.5115, Loss G: 0.7050]
# Epoch [0/5 Batch 2800/3166
#  Loss D: -1.5037, Loss G: 0.7032]
# Epoch [0/5 Batch 2900/3166
#  Loss D: -1.4899, Loss G: 0.6946]
# Epoch [0/5 Batch 3000/3166
#  Loss D: -1.4859, Loss G: 0.6981]
# Epoch [0/5 Batch 3100/3166
#  Loss D: -1.5058, Loss G: 0.7026]
# Epoch [1/5 Batch 0/3166
#  Loss D: -1.5101, Loss G: 0.7051]
# Epoch [1/5 Batch 100/3166
#  Loss D: -1.5025, Loss G: 0.7025]
# Epoch [1/5 Batch 200/3166
#  Loss D: -1.5110, Loss G: 0.7051]
# Epoch [1/5 Batch 300/3166
#  Loss D: -1.5098, Loss G: 0.7050]
# Epoch [1/5 Batch 400/3166
#  Loss D: -1.5139, Loss G: 0.7065]
# Epoch [1/5 Batch 500/3166
#  Loss D: -1.5104, Loss G: 0.7060]
# Epoch [1/5 Batch 600/3166
#  Loss D: -1.4586, Loss G: 0.6831]
# Epoch [1/5 Batch 700/3166
#  Loss D: -1.5112, Loss G: 0.7060]
# Epoch [1/5 Batch 800/3166
#  Loss D: -1.5133, Loss G: 0.7059]
# Epoch [1/5 Batch 900/3166
#  Loss D: -1.5137, Loss G: 0.7068]
# Epoch [1/5 Batch 1000/3166
#  Loss D: -1.4976, Loss G: 0.6871]
# Epoch [1/5 Batch 1100/3166
#  Loss D: -1.5148, Loss G: 0.7064]
# Epoch [1/5 Batch 1200/3166
#  Loss D: -1.4876, Loss G: 0.7029]
# Epoch [1/5 Batch 1300/3166
#  Loss D: -1.5067, Loss G: 0.7000]
# Epoch [1/5 Batch 1400/3166
#  Loss D: -1.5141, Loss G: 0.7069]
# Epoch [1/5 Batch 1500/3166
#  Loss D: -1.5169, Loss G: 0.7072]
# Epoch [1/5 Batch 1600/3166
#  Loss D: -1.5160, Loss G: 0.7065]
# Epoch [1/5 Batch 1700/3166
#  Loss D: -1.5176, Loss G: 0.7077]
# Epoch [1/5 Batch 1800/3166
#  Loss D: -1.5169, Loss G: 0.7058]
# Epoch [1/5 Batch 1900/3166
#  Loss D: -1.5185, Loss G: 0.7080]
# Epoch [1/5 Batch 2000/3166
#  Loss D: -1.5189, Loss G: 0.7076]
# Epoch [1/5 Batch 2100/3166
#  Loss D: -1.5170, Loss G: 0.7065]
# Epoch [1/5 Batch 2200/3166
#  Loss D: -1.5189, Loss G: 0.7082]
# Epoch [1/5 Batch 2300/3166
#  Loss D: -1.4405, Loss G: 0.6874]
# Epoch [1/5 Batch 2400/3166
#  Loss D: -1.5186, Loss G: 0.7076]
# Epoch [1/5 Batch 2500/3166
#  Loss D: -1.5173, Loss G: 0.7075]
# Epoch [1/5 Batch 2600/3166
#  Loss D: -1.5199, Loss G: 0.7079]
# Epoch [1/5 Batch 2700/3166
#  Loss D: -1.5170, Loss G: 0.7078]
# Epoch [1/5 Batch 2800/3166
#  Loss D: -1.5186, Loss G: 0.7085]
# Epoch [1/5 Batch 2900/3166
#  Loss D: -1.5203, Loss G: 0.7081]
# Epoch [1/5 Batch 3000/3166
#  Loss D: -1.5214, Loss G: 0.7084]
# Epoch [1/5 Batch 3100/3166
#  Loss D: -1.5186, Loss G: 0.7101]
# Epoch [2/5 Batch 0/3166
#  Loss D: -1.5130, Loss G: 0.7062]
# Epoch [2/5 Batch 100/3166
#  Loss D: -1.5213, Loss G: 0.7083]
# Epoch [2/5 Batch 200/3166
#  Loss D: -1.5215, Loss G: 0.7084]
# Epoch [2/5 Batch 300/3166
#  Loss D: -1.5185, Loss G: 0.7085]
# Epoch [2/5 Batch 400/3166
#  Loss D: -1.5210, Loss G: 0.7087]
# Epoch [2/5 Batch 500/3166
#  Loss D: -1.5213, Loss G: 0.7081]
# Epoch [2/5 Batch 600/3166
#  Loss D: -1.5201, Loss G: 0.7083]
# Epoch [2/5 Batch 700/3166
#  Loss D: -1.5156, Loss G: 0.7068]
# Epoch [2/5 Batch 800/3166
#  Loss D: -1.5199, Loss G: 0.7084]
# Epoch [2/5 Batch 900/3166
#  Loss D: -1.5183, Loss G: 0.7082]
# Epoch [2/5 Batch 1000/3166
#  Loss D: -1.5208, Loss G: 0.7087]
# Epoch [2/5 Batch 1100/3166
#  Loss D: -1.5225, Loss G: 0.7088]
# Epoch [2/5 Batch 1200/3166
#  Loss D: -1.5134, Loss G: 0.7030]
# Epoch [2/5 Batch 1300/3166
#  Loss D: -1.5218, Loss G: 0.7089]
# Epoch [2/5 Batch 1400/3166
#  Loss D: -1.5201, Loss G: 0.7081]
# Epoch [2/5 Batch 1500/3166
#  Loss D: -1.5231, Loss G: 0.7089]
# Epoch [2/5 Batch 1600/3166
#  Loss D: -1.5095, Loss G: 0.7027]
# Epoch [2/5 Batch 1700/3166
#  Loss D: -1.4935, Loss G: 0.6955]
# Epoch [2/5 Batch 1800/3166
#  Loss D: -1.5196, Loss G: 0.7083]
# Epoch [2/5 Batch 1900/3166
#  Loss D: -1.5217, Loss G: 0.7099]
# Epoch [2/5 Batch 2000/3166
#  Loss D: -1.5222, Loss G: 0.7083]
# Epoch [2/5 Batch 2100/3166
#  Loss D: -1.5208, Loss G: 0.7082]
# Epoch [2/5 Batch 2200/3166
#  Loss D: -1.5224, Loss G: 0.7081]
# Epoch [2/5 Batch 2300/3166
#  Loss D: -1.5210, Loss G: 0.7078]
# Epoch [2/5 Batch 2400/3166
#  Loss D: -1.5223, Loss G: 0.7086]
# Epoch [2/5 Batch 2500/3166
#  Loss D: -1.5217, Loss G: 0.7084]
# Epoch [2/5 Batch 2600/3166
#  Loss D: -1.5209, Loss G: 0.7086]
# Epoch [2/5 Batch 2700/3166
#  Loss D: -1.5211, Loss G: 0.7087]
# Epoch [2/5 Batch 2800/3166
#  Loss D: -1.5192, Loss G: 0.7081]
# Epoch [2/5 Batch 2900/3166
#  Loss D: -1.5208, Loss G: 0.7081]
# Epoch [2/5 Batch 3000/3166
#  Loss D: -1.4473, Loss G: 0.6962]
# Epoch [2/5 Batch 3100/3166
#  Loss D: -1.5151, Loss G: 0.7044]
# Epoch [3/5 Batch 0/3166
#  Loss D: -1.5206, Loss G: 0.7084]
# Epoch [3/5 Batch 100/3166
#  Loss D: -1.5191, Loss G: 0.7082]
# Epoch [3/5 Batch 200/3166
#  Loss D: -1.5193, Loss G: 0.7081]
# Epoch [3/5 Batch 300/3166
#  Loss D: -1.5224, Loss G: 0.7087]
# Epoch [3/5 Batch 400/3166
#  Loss D: -1.5212, Loss G: 0.7087]
# Epoch [3/5 Batch 500/3166
#  Loss D: -1.5188, Loss G: 0.7083]
# Epoch [3/5 Batch 600/3166
#  Loss D: -1.5201, Loss G: 0.7079]
# Epoch [3/5 Batch 700/3166
#  Loss D: -1.5203, Loss G: 0.7085]
# Epoch [3/5 Batch 800/3166
#  Loss D: -1.5218, Loss G: 0.7095]
# Epoch [3/5 Batch 900/3166
#  Loss D: -1.5223, Loss G: 0.7094]
# Epoch [3/5 Batch 1000/3166
#  Loss D: -1.5220, Loss G: 0.7088]
# Epoch [3/5 Batch 1100/3166
#  Loss D: -1.5164, Loss G: 0.7069]
# Epoch [3/5 Batch 1200/3166
#  Loss D: -1.5143, Loss G: 0.7063]
# Epoch [3/5 Batch 1300/3166
#  Loss D: -1.5229, Loss G: 0.7091]
# Epoch [3/5 Batch 1400/3166
#  Loss D: -1.5170, Loss G: 0.7062]
# Epoch [3/5 Batch 1500/3166
#  Loss D: -1.5211, Loss G: 0.7088]
# Epoch [3/5 Batch 1600/3166
#  Loss D: -1.5174, Loss G: 0.7069]
# Epoch [3/5 Batch 1700/3166
#  Loss D: -1.5127, Loss G: 0.7073]
# Epoch [3/5 Batch 1800/3166
#  Loss D: -1.4993, Loss G: 0.7018]
# Epoch [3/5 Batch 1900/3166
#  Loss D: -1.5199, Loss G: 0.7085]
# Epoch [3/5 Batch 2000/3166
#  Loss D: -1.5217, Loss G: 0.7084]
# Epoch [3/5 Batch 2100/3166
#  Loss D: -1.5237, Loss G: 0.7091]
# Epoch [3/5 Batch 2200/3166
#  Loss D: -1.5218, Loss G: 0.7089]
# Epoch [3/5 Batch 2300/3166
#  Loss D: -1.5230, Loss G: 0.7088]
# Epoch [3/5 Batch 2400/3166
#  Loss D: -1.5219, Loss G: 0.7086]
# Epoch [3/5 Batch 2500/3166
#  Loss D: -1.5220, Loss G: 0.7086]
# Epoch [3/5 Batch 2600/3166
#  Loss D: -1.5205, Loss G: 0.7079]
# Epoch [3/5 Batch 2700/3166
#  Loss D: -1.5220, Loss G: 0.7084]
# Epoch [3/5 Batch 2800/3166
#  Loss D: -1.5152, Loss G: 0.7062]
# Epoch [3/5 Batch 2900/3166
#  Loss D: -1.5210, Loss G: 0.7078]
# Epoch [3/5 Batch 3000/3166
#  Loss D: -1.5140, Loss G: 0.7062]
# Epoch [3/5 Batch 3100/3166
#  Loss D: -1.5228, Loss G: 0.7088]
# Epoch [4/5 Batch 0/3166
#  Loss D: -1.5231, Loss G: 0.7087]
# Epoch [4/5 Batch 100/3166
#  Loss D: -1.5203, Loss G: 0.7086]
# Epoch [4/5 Batch 200/3166
#  Loss D: -1.5217, Loss G: 0.7083]
# Epoch [4/5 Batch 300/3166
#  Loss D: -1.5205, Loss G: 0.7087]
# Epoch [4/5 Batch 400/3166
#  Loss D: -1.5232, Loss G: 0.7090]
# Epoch [4/5 Batch 500/3166
#  Loss D: -1.5183, Loss G: 0.7075]
# Epoch [4/5 Batch 600/3166
#  Loss D: -1.5160, Loss G: 0.7061]
# Epoch [4/5 Batch 700/3166
#  Loss D: -1.5232, Loss G: 0.7092]
# Epoch [4/5 Batch 800/3166
#  Loss D: -1.5177, Loss G: 0.7075]
# Epoch [4/5 Batch 900/3166
#  Loss D: -1.5207, Loss G: 0.7076]
# Epoch [4/5 Batch 1000/3166
#  Loss D: -1.5217, Loss G: 0.7086]
# Epoch [4/5 Batch 1100/3166
#  Loss D: -1.4865, Loss G: 0.6984]
# Epoch [4/5 Batch 1200/3166
#  Loss D: -1.5164, Loss G: 0.7076]
# Epoch [4/5 Batch 1300/3166
#  Loss D: -1.5214, Loss G: 0.7083]
# Epoch [4/5 Batch 1400/3166
#  Loss D: -1.5208, Loss G: 0.7086]
# Epoch [4/5 Batch 1500/3166
#  Loss D: -1.5239, Loss G: 0.7093]
# Epoch [4/5 Batch 1600/3166
#  Loss D: -1.5232, Loss G: 0.7088]
# Epoch [4/5 Batch 1700/3166
#  Loss D: -1.5215, Loss G: 0.7089]
# Epoch [4/5 Batch 1800/3166
#  Loss D: -1.5236, Loss G: 0.7099]
# Epoch [4/5 Batch 1900/3166
#  Loss D: -1.5213, Loss G: 0.7089]
# Epoch [4/5 Batch 2000/3166
#  Loss D: -1.5227, Loss G: 0.7090]
# Epoch [4/5 Batch 2100/3166
#  Loss D: -1.5231, Loss G: 0.7091]
# Epoch [4/5 Batch 2200/3166
#  Loss D: -1.5180, Loss G: 0.7069]
# Epoch [4/5 Batch 2300/3166
#  Loss D: -1.5215, Loss G: 0.7086]
# Epoch [4/5 Batch 2400/3166
#  Loss D: -1.5212, Loss G: 0.7079]
# Epoch [4/5 Batch 2500/3166
#  Loss D: -1.5190, Loss G: 0.7077]
# Epoch [4/5 Batch 2600/3166
#  Loss D: -1.5212, Loss G: 0.7090]
# Epoch [4/5 Batch 2700/3166
#  Loss D: -1.5236, Loss G: 0.7089]
# Epoch [4/5 Batch 2800/3166
#  Loss D: -1.5175, Loss G: 0.7079]
# Epoch [4/5 Batch 2900/3166
#  Loss D: -1.5224, Loss G: 0.7090]
# Epoch [4/5 Batch 3000/3166
#  Loss D: -1.5233, Loss G: 0.7089]
# Epoch [4/5 Batch 3100/3166
#  Loss D: -1.5204, Loss G: 0.7080]

# %%
# %tensorboard --logdir=logs/ --reload_interval=5
# Out:
# Reusing TensorBoard on port 6008 (pid 56358), started 0:00:13 ago. (Use '!kill 56358' to kill it.)
#       <iframe id="tensorboard-frame-48482675b1087cd4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-48482675b1087cd4");
#           const url = new URL("http://localhost");
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
